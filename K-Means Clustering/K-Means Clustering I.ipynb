# %% [markdown]
# # K Means Clustering
#
# ## Method Used
#
# K Means Clustering is an unsupervised learning algorithm that tries to cluster data based on their similarity. Unsupervised learning means that there is no outcome to be predicted, and the algorithm just tries to find patterns in the data. In k means clustering, we have the specify the number of clusters we want the data to be grouped into. The algorithm randomly assigns each observation to a cluster, and finds the centroid of each cluster. Then, the algorithm iterates through two steps:
# Reassign data points to the cluster whose centroid is closest. Calculate new centroid of each cluster. These two steps are repeated till the within cluster variation cannot be reduced any further. The within cluster variation is calculated as the sum of the euclidean distance between the data points and their respective cluster centroids.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Creating Some Data

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200,n_features=2,centers=4,cluster_std=1.8,random_state=101)

# %%
type(data)#tuple of arrays, data[0]: data points with two features, data[1]: group labels of data points
# Out:
# tuple

# %%
data[0][:5,:2]
# Out:
# array([[ -6.42884095,  10.14111739],
#        [  5.86867888,   5.20110356],
#        [ -0.37610937,   3.26427943],
#        [  2.16679181,   9.56300522],
#        [  5.0950857 ,   7.20752718]])

# %%
data[1] # group labels of data
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0, 0,
#        1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3, 0, 3,
#        3, 0, 1, 2, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0, 1, 2, 2,
#        1, 2, 0, 1, 3, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3, 2, 1, 1, 1,
#        1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1, 0, 3, 3, 2, 1,
#        2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3, 0, 1, 1, 3, 2, 3,
#        2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2, 0, 3, 2, 2, 2, 0, 2,
#        0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 3, 0, 3, 2, 2, 1, 2, 3, 1, 1, 3,
#        1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2, 1, 0])

# %% [markdown]
# # Visualizing Data

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1])

# %% [markdown]
# Here we create the data. Since we know the group labels, given in data[0][1] so we distingiush four groups easily in above scatter plot using c=data[0][1].

# %% [markdown]
# # Creating Clusters
# * Suppose we don't know the labels of above created data. We will distingush the above data using K-Means clustering and then compare with actual labels.

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_ ##centroids
# Out:
# array([[-0.0123077 ,  2.13407664],
#        [-9.46941837, -6.56081545],
#        [-4.13591321,  7.95389851],
#        [ 3.71749226,  7.01388735]])

# %%
kmeans.labels_ ## predicted group labels
# Out:
# array([2, 3, 0, 3, 3, 1, 3, 0, 3, 0, 2, 0, 3, 3, 2, 0, 3, 0, 1, 2, 1, 0, 0,
#        1, 2, 1, 1, 0, 3, 3, 2, 1, 3, 0, 0, 2, 1, 1, 1, 0, 1, 2, 2, 2, 0, 3,
#        2, 0, 1, 0, 0, 2, 3, 0, 1, 2, 0, 0, 2, 3, 1, 3, 1, 2, 3, 0, 1, 3, 3,
#        1, 3, 0, 1, 0, 1, 3, 3, 0, 2, 0, 0, 1, 3, 1, 0, 0, 0, 2, 0, 1, 1, 1,
#        1, 0, 0, 1, 3, 2, 1, 3, 0, 1, 0, 0, 3, 0, 1, 3, 1, 1, 3, 2, 2, 3, 1,
#        3, 2, 2, 3, 2, 0, 2, 0, 2, 0, 3, 2, 0, 1, 2, 2, 2, 0, 1, 1, 2, 3, 2,
#        3, 0, 1, 3, 1, 2, 2, 3, 0, 1, 2, 2, 2, 2, 0, 3, 0, 2, 3, 3, 3, 0, 3,
#        0, 0, 2, 1, 2, 0, 3, 2, 0, 3, 0, 2, 3, 0, 2, 3, 3, 1, 3, 2, 1, 1, 2,
#        1, 1, 1, 1, 1, 0, 1, 3, 3, 2, 1, 0, 3, 3, 1, 0])

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_)

# %% [markdown]
# Here is how the K-means clustring divides the data in 4 clusters.

# %%
f ,(ax1,ax2) = plt.subplots(1,2, sharey=True,figsize=(10,6))
ax1.set_title('K-Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_)
ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1])

# %% [markdown]
# ** NOTE: The colors are meaningless in reference between the two plots.**
